# %%
import numpy as np 
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import random as rd

# %%
df = pd.read_csv(r"C:\Users\hp\Desktop\heart.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
ds = pd.read_csv(r"C:\Users\hp\Desktop\airquality.csv")
ds
# Out:
#        StationId        Date  PM2.5    PM10     NO     NO2     NOx    NH3  \
# 0          AP001  24-11-2017  71.36  115.75   1.75   20.65   12.40  12.19
# 1          AP001  25-11-2017  81.40  124.50   1.44   20.50   12.08  10.72
# 2          AP001  26-11-2017  78.32  129.06   1.26   26.00   14.85  10.28
# 3          AP001  27-11-2017  88.76  135.32   6.60   30.85   21.77  12.91
# 4          AP001  28-11-2017  64.18  104.09   2.56   28.07   17.01  11.42
# ...          ...         ...    ...     ...    ...     ...     ...    ...
# 108030     WB013  27-06-2020   8.65   16.46    NaN     NaN     NaN    NaN
# 108031     WB013  28-06-2020  11.80   18.47    NaN     NaN     NaN    NaN
# 108032     WB013  29-06-2020  18.60   32.26  13.65  200.87  214.20  11.40
# 108033     WB013  30-06-2020  16.07   39.30   7.56   29.13   36.69  29.26
# 108034     WB013  01-07-2020  10.50   36.50   7.78   22.50   30.25  27.23
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
ds.head()
# Out:
#   StationId        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 0     AP001  24-11-2017  71.36  115.75  1.75  20.65  12.40  12.19  0.10
# 1     AP001  25-11-2017  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2     AP001  26-11-2017  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 3     AP001  27-11-2017  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 4     AP001  28-11-2017  64.18  104.09  2.56  28.07  17.01  11.42  0.09
#
#      SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 0  10.76  109.26     0.17     5.92    0.10    NaN        NaN
# 1  15.24  127.09     0.20     6.50    0.06  184.0   Moderate
# 2  26.96  117.44     0.22     7.95    0.08  197.0   Moderate
# 3  33.59  111.81     0.29     7.63    0.12  198.0   Moderate
# 4  19.00  138.18     0.17     5.02    0.07  188.0   Moderate

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
ds.tail()
# Out:
#        StationId        Date  PM2.5   PM10     NO     NO2     NOx    NH3  \
# 108030     WB013  27-06-2020   8.65  16.46    NaN     NaN     NaN    NaN
# 108031     WB013  28-06-2020  11.80  18.47    NaN     NaN     NaN    NaN
# 108032     WB013  29-06-2020  18.60  32.26  13.65  200.87  214.20  11.40
# 108033     WB013  30-06-2020  16.07  39.30   7.56   29.13   36.69  29.26
# 108034     WB013  01-07-2020  10.50  36.50   7.78   22.50   30.25  27.23
#
#           CO   SO2     O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 108030  0.69  4.36  30.59     1.32     7.26     NaN  50.0          Good
# 108031  0.68  3.49  38.95     1.42     7.92     NaN  65.0  Satisfactory
# 108032  0.78  5.12  38.17     3.52     8.64     NaN  63.0  Satisfactory
# 108033  0.69  5.88  29.64     1.86     8.40     NaN  57.0  Satisfactory
# 108034  0.58  2.80  13.10     1.31     7.39     NaN  59.0  Satisfactory

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108035 entries, 0 to 108034
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   StationId   108035 non-null  object
#  1   Date        108035 non-null  object
#  2   PM2.5       86410 non-null   float64
#  3   PM10        65329 non-null   float64
#  4   NO          90929 non-null   float64
#  5   NO2         91488 non-null   float64
#  6   NOx         92535 non-null   float64
#  7   NH3         59930 non-null   float64
#  8   CO          95037 non-null   float64
#  9   SO2         82831 non-null   float64
#  10  O3          82467 non-null   float64
#  11  Benzene     76580 non-null   float64
#  12  Toluene     69333 non-null   float64
#  13  Xylene      22898 non-null   float64
#  14  AQI         87025 non-null   float64
#  15  AQI_Bucket  87025 non-null   object
# dtypes: float64(13), object(3)
# memory usage: 13.2+ MB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
ds.isnull().sum()
# Out:
# StationId         0
# Date              0
# PM2.5         21625
# PM10          42706
# NO            17106
# NO2           16547
# NOx           15500
# NH3           48105
# CO            12998
# SO2           25204
# O3            25568
# Benzene       31455
# Toluene       38702
# Xylene        85137
# AQI           21010
# AQI_Bucket    21010
# dtype: int64

# %%
df.dropna()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
ds.dropna()
# Out:
#        StationId        Date   PM2.5    PM10      NO    NO2     NOx    NH3  \
# 1          AP001  25-11-2017   81.40  124.50    1.44  20.50   12.08  10.72
# 2          AP001  26-11-2017   78.32  129.06    1.26  26.00   14.85  10.28
# 3          AP001  27-11-2017   88.76  135.32    6.60  30.85   21.77  12.91
# 4          AP001  28-11-2017   64.18  104.09    2.56  28.07   17.01  11.42
# 5          AP001  29-11-2017   72.47  114.84    5.23  23.20   16.59  12.25
# ...          ...         ...     ...     ...     ...    ...     ...    ...
# 106143     WB010  10-02-2020   80.93  174.84   82.96  56.74  139.70  29.32
# 106144     WB010  11-02-2020  103.75  217.89  139.58  63.28  181.55  27.56
# 106145     WB010  12-02-2020  115.40  225.76  193.19  70.41  213.77  35.25
# 106146     WB010  13-02-2020   97.37  179.87  105.12  64.34  169.46  36.24
# 106147     WB010  14-02-2020   89.13  179.89   78.47  56.37  134.84  37.98
#
# ...

# %%
ds1 = ds.loc[111:999,['StationId','CO','SO2','AQI']]
ds1
# Out:
#     StationId    CO    SO2    AQI
# 111     AP001  0.58  11.33   60.0
# 112     AP001  0.58   6.37   51.0
# 113     AP001  0.70  12.47   61.0
# 114     AP001  0.80  10.57   90.0
# 115     AP001  0.70   8.89   74.0
# ..        ...   ...    ...    ...
# 995     AP005  1.02  35.15  101.0
# 996     AP005  1.07  35.46   89.0
# 997     AP005  1.15  26.20   83.0
# 998     AP005  1.03  32.12   90.0
# 999     AP005  1.10  39.42  102.0
#
# [889 rows x 4 columns]

# %%
ds2 = ds.iloc[[1,3,5,2,4,22,43,54,67,7,8,9,50,10,11]]
ds2
# Out:
#    StationId        Date  PM2.5    PM10     NO    NO2    NOx    NH3    CO  \
# 1      AP001  25-11-2017  81.40  124.50   1.44  20.50  12.08  10.72  0.12
# 3      AP001  27-11-2017  88.76  135.32   6.60  30.85  21.77  12.91  0.11
# 5      AP001  29-11-2017  72.47  114.84   5.23  23.20  16.59  12.25  0.16
# 2      AP001  26-11-2017  78.32  129.06   1.26  26.00  14.85  10.28  0.14
# 4      AP001  28-11-2017  64.18  104.09   2.56  28.07  17.01  11.42  0.09
# 22     AP001  16-12-2017  79.76  129.81   8.77  40.92  28.84  15.56  0.17
# 43     AP001  06-01-2018  85.15  151.97  11.05  61.55  41.72  18.71  0.07
# 54     AP001  17-01-2018  68.34  104.45   3.71  26.26  16.99  20.29  0.06
# 67     AP001  30-01-2018  78.23  140.66   5.36  45.76  28.70  21.73  0.05
# 7      AP001  01-12-2017  73.96  113.56   4.58  19.29  13.97  10.95  0.10
# 8      AP001  02-12-2017  89.90  140.20   7.71  26.19  19.87  13.12  0.10
# 9      AP001  03-12-2017  87.14  130.52   0.97  21.31  12.12  14.36  0.15
# ...

# %%
df1 =df.loc[11:199,['age','sex','chol','thalach']]
df1
# Out:
#      age  sex  chol  thalach
# 11    43    0   341      136
# 12    34    0   210      192
# 13    51    1   298      122
# 14    52    1   204      156
# 15    34    0   210      192
# ..   ...  ...   ...      ...
# 195   59    1   212      157
# 196   58    1   234      156
# 197   45    1   260      185
# 198   60    0   318      160
# 199   50    1   200      126
#
# [189 rows x 4 columns]

# %%
ds_integration = pd.concat([ds1,ds2])
ds_integration
# Out:
#     StationId    CO    SO2    AQI        Date  PM2.5    PM10    NO    NO2  \
# 111     AP001  0.58  11.33   60.0         NaN    NaN     NaN   NaN    NaN
# 112     AP001  0.58   6.37   51.0         NaN    NaN     NaN   NaN    NaN
# 113     AP001  0.70  12.47   61.0         NaN    NaN     NaN   NaN    NaN
# 114     AP001  0.80  10.57   90.0         NaN    NaN     NaN   NaN    NaN
# 115     AP001  0.70   8.89   74.0         NaN    NaN     NaN   NaN    NaN
# ..        ...   ...    ...    ...         ...    ...     ...   ...    ...
# 8       AP001  0.10  19.37  191.0  02-12-2017  89.90  140.20  7.71  26.19
# 9       AP001  0.15  11.41  227.0  03-12-2017  87.14  130.52  0.97  21.31
# 50      AP001  0.05  14.36  214.0  13-01-2018  77.51  125.01  3.85  36.41
# 10      AP001  0.18   9.84  168.0  04-12-2017  84.64  125.00  4.02  26.98
# 11      AP001  0.12  14.02  198.0  05-12-2017  88.36  121.77  3.70  20.23
#
#        NOx    NH3      O3  Benzene  Toluene  Xylene AQI_Bucket
# ...

# %%
ds_integration.transpose()
# Out:
#               111    112    113    114    115    116    117    118    119  \
# StationId   AP001  AP001  AP001  AP001  AP001  AP001  AP001  AP001  AP001
# CO           0.58   0.58    0.7    0.8    0.7   0.57   0.92   0.59    0.6
# SO2         11.33   6.37  12.47  10.57   8.89   7.04  15.45  16.81  15.55
# AQI          60.0   51.0   61.0   90.0   74.0   76.0    NaN   92.0   93.0
# Date          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# PM2.5         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# PM10          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# NO            NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# NO2           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# NOx           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# NH3           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# O3            NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
ds.drop(columns ='SO2')
# Out:
#        StationId        Date  PM2.5    PM10     NO     NO2     NOx    NH3  \
# 0          AP001  24-11-2017  71.36  115.75   1.75   20.65   12.40  12.19
# 1          AP001  25-11-2017  81.40  124.50   1.44   20.50   12.08  10.72
# 2          AP001  26-11-2017  78.32  129.06   1.26   26.00   14.85  10.28
# 3          AP001  27-11-2017  88.76  135.32   6.60   30.85   21.77  12.91
# 4          AP001  28-11-2017  64.18  104.09   2.56   28.07   17.01  11.42
# ...          ...         ...    ...     ...    ...     ...     ...    ...
# 108030     WB013  27-06-2020   8.65   16.46    NaN     NaN     NaN    NaN
# 108031     WB013  28-06-2020  11.80   18.47    NaN     NaN     NaN    NaN
# 108032     WB013  29-06-2020  18.60   32.26  13.65  200.87  214.20  11.40
# 108033     WB013  30-06-2020  16.07   39.30   7.56   29.13   36.69  29.26
# 108034     WB013  01-07-2020  10.50   36.50   7.78   22.50   30.25  27.23
#
#           CO      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# ...

# %%
ds.melt()
# Out:
#            variable         value
# 0         StationId         AP001
# 1         StationId         AP001
# 2         StationId         AP001
# 3         StationId         AP001
# 4         StationId         AP001
# ...             ...           ...
# 1728555  AQI_Bucket          Good
# 1728556  AQI_Bucket  Satisfactory
# 1728557  AQI_Bucket  Satisfactory
# 1728558  AQI_Bucket  Satisfactory
# 1728559  AQI_Bucket  Satisfactory
#
# [1728560 rows x 2 columns]

# %%
data_merged = pd.concat([ds,df])
data_merged
# Out:
#      StationId        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 0        AP001  24-11-2017  71.36  115.75  1.75  20.65  12.40  12.19  0.10
# 1        AP001  25-11-2017  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2        AP001  26-11-2017  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 3        AP001  27-11-2017  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 4        AP001  28-11-2017  64.18  104.09  2.56  28.07  17.01  11.42  0.09
# ...        ...         ...    ...     ...   ...    ...    ...    ...   ...
# 1020       NaN         NaN    NaN     NaN   NaN    NaN    NaN    NaN   NaN
# 1021       NaN         NaN    NaN     NaN   NaN    NaN    NaN    NaN   NaN
# 1022       NaN         NaN    NaN     NaN   NaN    NaN    NaN    NaN   NaN
# 1023       NaN         NaN    NaN     NaN   NaN    NaN    NaN    NaN   NaN
# 1024       NaN         NaN    NaN     NaN   NaN    NaN    NaN    NaN   NaN
#
# ...

# %%
from sklearn import linear_model,metrics
X = df[['age']]
Y = df[['thal']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size = 0.2,random_state=1)

# %%
len(X_train)
len(X_test)
# Out:
# 205

# %%
reg = linear_model.LinearRegression()

# %%
print(X_train)
# Out:
#      age
# 880   57
# 358   59
# 772   62
# 682   59
# 848   58
# ..   ...
# 905   64
# 767   68
# 72    56
# 908   62
# 235   64
#
# [820 rows x 1 columns]

# %%
model = reg.fit(X_train,Y_train)

# %%
r_sq = reg.score(X_train,Y_train)
print("Determination Of Coefficient:",r_sq)
# Out:
# Determination Of Coefficient: 0.008792008347529245

# %%
print("Intercept:",model.intercept_)
# Out:
# Intercept: [1.97461867]

# %%
print("Slope:",model.coef_)
# Out:
# Slope: [[0.00633286]]

# %%
Y_pred =model.predict(X_test)
print("Predicated response:",Y_pred,sep='\n')
# Out:
# Predicated response:
# [[2.35459004]
#  [2.29759433]
#  [2.24059863]
#  [2.38625432]
#  [2.22793292]
#  [2.32292576]
#  [2.23426577]
#  [2.33559147]
#  [2.34192433]
#  [2.34192433]
#  [2.22793292]
#  [2.24059863]
#  [2.25326434]
#  [2.4179186 ]
#  [2.26593005]
#  [2.37992147]
#  [2.37358861]
#  [2.23426577]
#  [2.24693148]
#  [2.34192433]
#  [2.29126148]
#  [2.35459004]
#  [2.39258718]
#  [2.34192433]
#  [2.22793292]
#  [2.34192433]
#  [2.37358861]
#  [2.32925862]
#  [2.31026005]
#  [2.27859577]
#  [2.19626863]
#  [2.39258718]
#  [2.34192433]
#  [2.33559147]
#  [2.29126148]
#  [2.36725575]
#  [2.32292576]
#  [2.33559147]
#  [2.37992147]
#  [2.30392719]
#  [2.36725575]
#  [2.39892003]
#  [2.26593005]
#  [2.29126148]
#  [2.35459004]
#  [2.23426577]
#  [2.35459004]
#  [2.34825718]
#  [2.30392719]
#  [2.42425146]
#  [2.30392719]
#  [2.25326434]
#  [2.2152672 ]
#  [2.3165929 ]
#  [2.32925862]
#  [2.39258718]
#  [2.38625432]
#  [2.30392719]
#  [2.34192433]
#  [2.35459004]
#  [2.29126148]
# ...
